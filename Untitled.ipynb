# %%
# load json and create model'
import tensorflow.keras as keras

# %%
from tensorflow.keras.models import model_from_json
json_file = open('p1_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("p1_model.h5")
# evaluate loaded model on test data
import pandas as pd
data = pd.read_csv("datasets/p1_dataset.csv")
x = data.iloc[:,1:-1].values
y = data.iloc[:,-1].values
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(y)
y = y.reshape((len(y),1))

# %%
loaded_model.predict_on_batch(x)
# Out:
# array([[0.5659621 ],
#        [0.50893724],
#        [0.5560989 ],
#        [0.59081995],
#        [0.59878004],
#        [0.7049147 ],
#        [0.6545755 ],
#        [0.58220863],
#        [0.5678898 ],
#        [0.51527345],
#        [0.5735972 ],
#        [0.63127327],
#        [0.4945711 ],
#        [0.5156229 ],
#        [0.50956225],
#        [0.70969516],
#        [0.6310165 ],
#        [0.59562314],
#        [0.6118452 ],
#        [0.66666657],
#        [0.5579773 ],
#        [0.6788048 ],
#        [0.58606225],
#        [0.6753232 ],
#        [0.6866967 ],
#        [0.53059125],
#        [0.66000545],
#        [0.5691415 ],
#        [0.53314406],
#        [0.61152244],
#        [0.5787043 ],
#        [0.5803507 ],
#        [0.64461803],
#        [0.6274424 ],
#        [0.51527345],
#        [0.49173915],
#        [0.48630726],
#        [0.51527345],
#        [0.5669381 ],
#        [0.5669136 ],
#        [0.5924437 ],
#        [0.45864344],
#        [0.601984  ],
#        [0.73685086],
#        [0.77022576],
#        [0.55389357],
#        [0.65547985],
#        [0.5898685 ],
#        [0.58889234],
#        [0.5462111 ],
#        [1.18838   ],
#        [1.2728628 ],
#        [1.2527623 ],
#        [1.1011167 ],
#        [1.2059501 ],
#        [1.2505139 ],
#        [1.3722908 ],
#        [0.9921049 ],
#        [1.1488558 ],
#        [1.2282804 ],
#        [0.9436672 ],
#        [1.2588683 ],
#        [0.9181347 ],
#        [1.2734666 ],
#        [1.1170614 ],
#        [1.1613189 ],
#        [1.3601774 ],
#        [1.0548143 ],
#        [1.1282232 ],
#        [1.0430706 ],
#        [1.4937452 ],
#        [1.096961  ],
#        [1.2393949 ],
#        [1.1966214 ],
#        [1.1240224 ],
#        [1.1590909 ],
#        [1.1673529 ],
#        [1.3436266 ],
#        [1.2814742 ],
#        [0.9417394 ],
#        [1.0223682 ],
#        [0.9742326 ],
#        [1.0771874 ],
#        [1.3869363 ],
#        [1.3907673 ],
#        [1.3987501 ],
#        [1.2464036 ],
#        [1.052654  ],
#        [1.2269567 ],
#        [1.1361625 ],
#        [1.1979223 ],
#        [1.2725152 ],
#        [1.0781391 ],
#        [0.95928675],
#        [1.1928625 ],
#        [1.2004751 ],
#        [1.2126132 ],
#        [1.1546128 ],
#        [0.95327544],
#        [1.1766161 ],
#        [1.8794101 ],
#        [1.5065099 ],
#        [1.5673615 ],
#        [1.5277921 ],
#        [1.670319  ],
#        [1.6202079 ],
#        [1.4389502 ],
#        [1.5041631 ],
#        [1.4334692 ],
#        [1.8127984 ],
#        [1.5167205 ],
#        [1.4516886 ],
#        [1.5393487 ],
#        [1.497946  ],
#        [1.6723391 ],
#        [1.6579484 ],
#        [1.4962503 ],
#        [1.7932323 ],
#        [1.649567  ],
#        [1.2511859 ],
#        [1.6553708 ],
#        [1.5473354 ],
#        [1.5586802 ],
#        [1.3634247 ],
#        [1.6441618 ],
#        [1.5166034 ],
#        [1.3777682 ],
#        [1.4465836 ],
#        [1.5839576 ],
#        [1.3852859 ],
#        [1.4640571 ],
#        [1.6478962 ],
#        [1.613619  ],
#        [1.3289129 ],
#        [1.3871685 ],
#        [1.571863  ],
#        [1.7933742 ],
#        [1.5290686 ],
#        [1.4434042 ],
#        [1.523102  ],
#        [1.6796252 ],
#        [1.527001  ],
#        [1.5065099 ],
#        [1.7076153 ],
#        [1.7628065 ],
#        [1.5585425 ],
#        [1.3765143 ],
#        [1.500149  ],
#        [1.7420589 ],
#        [1.5141226 ]], dtype=float32)
